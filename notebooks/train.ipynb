# %%
import sys
sys.path.append(r"C:\Users\Owner\pneumonia_recognition\src")

from train import train

# %%
WINDOWS_CONFIG = {
    "epochs": 3,
    "training_results_path": r"C:\Users\Owner\pneumonia_recognition\results\train_results",
    "model_path": r"C:\Users\Owner\pneumonia_recognition\models",
    "training_data_path": r"C:\Users\Owner\pneumonia_recognition\data\train",
    "plot": True,
    "evaluation_data_path": r"C:\Users\Owner\pneumonia_recognition\data\val",
    "evaluation_save_path": r"C:\Users\Owner\pneumonia_recognition\results\eval_results",
    "test_save_path": r"C:\Users\Owner\pneumonia_recognition\results\test_results",
    "test_data_dir": r"C:\Users\Owner\pneumonia_recognition\data\test"
}

# %%
train(
    epochs= WINDOWS_CONFIG['epochs'],
    save_file_path= WINDOWS_CONFIG['training_results_path'],
    model_path=WINDOWS_CONFIG['model_path'],
    data_dir= WINDOWS_CONFIG['training_data_path'],
    plot=True
)
# Out:
# Epoch 1/3
#
#             Loss: 72.9303
#             Acc: 0.7832 | Prec: 0.7753 | Recall: 0.9972 | F1: 0.8723
#             AUC: 0.8837
#             TP:3864 FP:1120 TN:221 FN:11
#
#
# Epoch 2/3
#
#             Loss: 48.2203
#             Acc: 0.9030 | Prec: 0.8963 | Recall: 0.9832 | F1: 0.9377
#             AUC: 0.9699
#             TP:3810 FP:441 TN:900 FN:65
#
#
# Epoch 3/3
#
#             Loss: 38.2006
#             Acc: 0.9287 | Prec: 0.9309 | Recall: 0.9765 | F1: 0.9531
#             AUC: 0.9780
#             TP:3784 FP:281 TN:1060 FN:91
#
# accuracy_scores: [0.7831671779141104, 0.9029907975460123, 0.928680981595092]
# precision_scores: [0.7752808988764045, 0.8962597035991532, 0.9308733087330874]
# recall_scores: [0.9971612903225806, 0.983225806451613, 0.976516129032258]
# f1_scores: [0.8723332204537758, 0.9377307408318976, 0.9531486146095718]
