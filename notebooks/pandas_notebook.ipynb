# %%
import pandas as pd

# %%
dfs = []

# %%
for i in range(10):
    dfs.append(pd.DataFrame({'i': [i], 'x': [i + 1]}))

# %%
df = pd.concat(dfs, ignore_index=True)
df.to_csv("/Users/christianrafferty/pneumonia_recognition/notebooks/no_index_data.csv", index=False)

# %%
df = pd.concat(dfs, ignore_index=True)
df.to_csv("/Users/christianrafferty/pneumonia_recognition/notebooks/index_data.csv", index=True)
